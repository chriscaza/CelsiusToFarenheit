# %% [markdown]
# <a href="https://colab.research.google.com/github/chriscaza/CelsiusToFarenheit/blob/main/Red_neuronal_CelsiusToFarenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
celcius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
farenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer = tf.keras.optimizers.Adam(0.01),
    loss='mean_squared_error'
)

# %%
print("Comezando entrenamiento...")
historial = modelo.fit(celcius, farenheit, epochs=300, verbose=False)
print("Modelo entrenado!")
# Out:
# Comezando entrenamiento...
# Modelo entrenado!

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoca")
plt.ylabel("Magnitud de pérdida")
plt.plot(historial.history["loss"])

# %%
print("Hagamos una predicción!")
resultado = modelo.predict([100.0])
print("El resultado es " + str(resultado) + " farenheit!")
# Out:
# Hagamos una predicción!
# 1/1 [==============================] - 0s 64ms/step
# El resultado es [[211.74744]] farenheit!
